# %% [markdown]
# # 미니 프로젝트: 가위바위보 게임

# %% [markdown]
# <img src="https://drive.google.com/uc?id=11DKT5fVMQCnYPZxYOIH3yXNX9e4k7x-K">
# <br>

# %% [markdown]
# ## 사용자 입력함수 작성

# %%
def match():
    # 초기설정 수행
    u_choice, c_choice = 0, 0
    match_score = 0
    choice_dic = {"1":"가위", "2":"바위", "3":"보"}
    result_dic = {0:"결과는 무승부입니다.", 1:"결과는 사용자의 승리입니다.", -1:"결과는 컴퓨터의 승리입니다."}
    
    # 사용자 선택 가져오기
    u_choice = user_choice()
    
    # 컴퓨터 선택 가져오기
    c_choice = com_choice()
    
    # 승부 결과 가져오기
    match_score = who_win2(u_choice, c_choice)
    
    # 승부 결과 출력
    print(f"사용자 {choice_dic[u_choice]} vs 컴퓨터 {choice_dic[c_choice]}. {result_dic[match_score]}")

# %% [markdown]
# ## 컴퓨터 선택 결정

# %%
# 컴퓨터의 선택을 1(가위), 2(바위), 3(보) 중 하나로 랜덤하게 가져옴
def com_choice():
    import random as r
    return str(r.randint(1,3))

# %% [markdown]
# ## 승부 판단 함수 작성

# %%
def who_win(u_choice, c_choice):
    if u_choice == "1": # 참가자가 가위를 냈을 때
        if c_choice == "1": # 컴퓨터가 가위를 냈을 때
            return 0
        elif c_choice == "2": # 컴퓨터가 바위를 냈을 때
            return -1
        else:
            return 1  # 컴퓨터가 보를 냈을 때
    elif u_choice == "2": # 참가자가 바위를 냈을 때
        if c_choice == "1":
            return 1
        elif c_choice == "2":
            return 0
        else:
            return -1
    else: # 참가자가 보를 냈을 때
        if c_choice == "1":
            return -1
        elif c_choice == "2":
            return 1
        else:
            return 0

# %% [markdown]
# # 메인 함수 match() 작성

# %%
def match():
    # 초기설정 수행
    u_choice, c_choice = 0, 0
    match_score = 0
    choice_dic = {"1":"가위", "2":"바위", "3":"보"}
    result_dic = {0:"결과는 무승부입니다.", 1:"결과는 사용자의 승리입니다.", -1:"결과는 컴퓨터의 승리입니다."}
    
    # 사용자 선택 가져오기
    u_choice = user_choice()
    
    # 컴퓨터 선택 가져오기
    c_choice = com_choice()
    
    # 승부 결과 가져오기
    match_score = who_win2(u_choice, c_choice)
    
    # 승부 결과 출력
    print(f"사용자 {choice_dic[u_choice]} vs 컴퓨터 {choice_dic[c_choice]}. {result_dic[match_score]}")

# %% [markdown]
# # 과제 1. who_win3 함수 작성 (20점)

# %%
# 딕셔너리를 사용해서 if문 없이 who_win()함수과 동일한 기능을 구현하세요
def who_win3(u_choice, c_choice):
    i = 0
    j = 0

    while(u_choice != i and c_choice != j):
        while(u_choice != i):
            i = i+1
        while(c_choice != j):
            j = j+1
        print("i값 :", i, "j값 :", j)
    dec = i-j
    while(u_choice == i and c_choice == j):
        while(dec == 1 and (u_choice == 2 or u_choice == 3)):
            D = "이김"
            #print("i값 :", i, "j값 :", j, "//이김")
            break

        while(dec == -2 and u_choice == 1):
            D = "이김"
            #print("i값 :", i, "j값 :", j, "//이김")
            break

        while(dec == -1 and (u_choice == 1 or u_choice == 2)):
            D = "짐"
            #print("i값 :", i, "j값 :", j, "//짐")
            break

        while(dec == 2 and u_choice == 3):
            D = "짐"
            #print("i값 :", i, "j값 :", j, "//짐")
            break

        while(dec == 0):
            D = "비김"
            #print("i값 :", i, "j값 :", j, "//비김")
            break
        win_dec = {'이김': 1, '짐': -1, '비김': 0}
        return win_dec.get(D)

# %% [markdown]
# # 과제 2. 프로그램을 수정하여 5판 3선승제 규칙을 구현하세요 (50점)
#
# ### 1) 최대 5번의 게임을 할 수 있고 먼저 3번 승리한 쪽이 종합 우승입니다. 단계별로 적절한 메시지가 필요합니다.
# ### 2) 사용자의 이름을 입력받아 사용하세요
# ### 3) 경기 종료 후 종합적인 승패 결과를 출력해야 합니다.
# ### 4) 경기가 끝난 후 다시 게임을 시작할 것인지 물어보고 사용자의 선택에 따라 진행합니다.(재경기 또는 종료)

# %%
def match():
    # 초기설정 수행
    u_choice, c_choice = 0, 0
    match_score = 0
    choice_dic = {1: "가위", 2: "바위", 3: "보"}
    result_dic = {0: "결과는 무승부입니다.",
                  1: "결과는 사용자의 승리입니다.", -1: "결과는 컴퓨터의 승리입니다."}

    # 사용자 선택 가져오기
    u_choice = user_choice()

    # 컴퓨터 선택 가져오기
    c_choice = com_choice()

    # 승부 결과 가져오기
    match_score = who_win(u_choice, c_choice)
    # 승부 결과 출력
    print(
        f"\n사용자 {choice_dic[u_choice]} vs 컴퓨터 {choice_dic[c_choice]} 입니다. {result_dic[match_score]}\n")
    return match_score


def user_choice():
    re = 1
    i = float(input("// 가위 : 1 바위 : 2 보 : 3 // : "))
    while re:
        if i > 3 or i < 0:
            i = int(input("//다시 입력!!!//\n //가위 : 1 바위 : 2 보 : 3 // : "))
        elif i % 1 != 0:
            i = int(input("//다시 입력!!!//\n //가위 : 1 바위 : 2 보 : 3 // : "))
        else:
            re = 0
            break
    return i


def com_choice():
    import random as r
    return r.randint(1, 3)


def who_win(u_choice, c_choice):
    if u_choice == "1":  # 참가자가 가위를 냈을 때
        if c_choice == "1":  # 컴퓨터가 가위를 냈을 때
            return 0
        elif c_choice == "2":  # 컴퓨터가 바위를 냈을 때
            return -1
        else:
            return 1  # 컴퓨터가 보를 냈을 때
    elif u_choice == "2":  # 참가자가 바위를 냈을 때
        if c_choice == "1":
            return 1
        elif c_choice == "2":
            return 0
        else:
            return -1
    else:  # 참가자가 보를 냈을 때
        if c_choice == "1":
            return -1
        elif c_choice == "2":
            return 1
        else:
            return 0


def again_fn():
    again = int(input("재대결 : 1 , 끝내기 : 0    : "))
    while True:
        if again == 1:
            v = True
            break
        elif again == 0:
            v = False
            break
        else:
            again = int(input("//다시 입력!!!//\n재대결 : 1 , 끝내기 : 0"))
    return again


u_score = 0
c_score = 0
v = True
match_cnt = 1
while(v):
    if match_cnt == 5:
        print("마지막 매치 입니다!")
    else:
        print(f"{match_cnt}번째 매치 입니다!")
    score_dec = match()
    if score_dec == 1:
        u_score = u_score+1
    elif score_dec == -1:
        c_score = c_score+1
    else:
        u_score = u_score+1
        c_score = c_score+1

    if match == 5:
        if u_score > c_score:
            print("최종 승리자는 유저 입니다!")
        elif u_score < c_score:
            print("최종 승리자는 컴퓨터 입니다!")
        else:
            print("최종 게임 결과는 무승부 입니다!")
        v = again_fn()
        if v == True:
            u_score = 0
            c_score = 0
            match_cnt = 0
    else:
        if u_score == c_score and match_cnt == 3:
            print("최종 게임 결과는 무승부 입니다!\n")
            v = again_fn()
            if v == True:
                u_score = 0
                c_score = 0
                match_cnt = 0
        elif u_score >= 3:
            print("최종 승리자는 유저 입니다!")
            v = again_fn()
            if v == True:
                u_score = 0
                c_score = 0
                match_cnt = 0
        elif u_score >= 3:
            print("최종 승리자는 컴퓨터 입니다!")
            v = again_fn()
            if v == True:
                u_score = 0
                c_score = 0
                match_cnt = 0
    match_cnt = match_cnt+1
